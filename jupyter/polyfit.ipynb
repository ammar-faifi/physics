# %%
# import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sympy as sp

# %%
y =[2, 4, 6, 5, 4, 6, 5, 6, 7, 9]
x = np.arange(0,10)

f1 = np.poly1d(np.polyfit(x, y, 1))
f2 = np.poly1d(np.polyfit(x, y, 5))

print(f2)

plt.plot(x, y, label="Original")
plt.plot(x, f2(x), label="Poly")
plt.plot(x, f1(x), label="Line")
plt.legend()
plt.show()

i=0
exp=0
for c in f2.c :
    exp = exp + f"+{c:0.5f} * x**{ord-i}"
    i += 1
# Out:
#           5           4          3     2
# 0.001538 x - 0.04015 x + 0.4157 x - 2 x + 4.289 x + 1.88
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-562d320e0a0e> in <module>
#      16 exp=0
#      17 for c in f2.c :
# ---> 18     exp = exp + f"+{c:0.5f} * x**{ord-i}"
#      19     i += 1
#
# TypeError: unsupported operand type(s) for -: 'builtin_function_or_method' and 'int'
